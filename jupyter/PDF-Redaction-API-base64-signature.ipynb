# %% [markdown]
# <p align="center">
#   <br/>
#     <a href="https://pdf-redaction.com/" target="_blank"><img alt="PDF Redaction"
#     src="https://pdf-redaction.com/images/pdf-redaction-logo.svg" width="450" style="max-width: 100%;"></a>
#   <br/>
# </p>
#
# <p align="center">
#     <i>Secure Your PDFs with AI-powered Redaction</i>
# </p>
#
# <p align="center">
#     <a target="_blank" href="https://colab.research.google
#     .com/github/StabRise/pdf-redaction-api/blob/main/jupyter/PDF-Redaction
#     -API-base64-signature.ipynb">
#       <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
#     </a>
#     <a href="https://github.com/stabrise/spark-pdf/blob/main/LICENSE"><img alt="GitHub" src="https://img.shields.io/github/license/stabrise/spark-pdf.svg?color=blue"></a>
#     <a href="https://stabrise.com"><img alt="StabRise" src="https://img.shields.io/badge/powered%20by-StabRise-orange.svg?style=flat&colorA=E1523D&colorB=blue"/>
#     </a>
# </p>
#
# # Example of using PDF Redaction API for redact signatures
#
# **Source**: [https://github.com/StabRise/pdf-redaction-api](https://github.com/StabRise/pdf-redaction-api)
#
# [Swagger API documentation](https://stabrise-com--pdf-redaction-api-wrapper.modal.run/api/docs)
#
# Web UI: [https://pdf-redaction.com](https://pdf-redaction.com)
#
# For generate API Key please go to the: [https://pdf-redaction.com/apikeys/](https://pdf-redaction.com/apikeys/)
#
# For check usage: [https://pdf-redaction.com/apikeys/usage/](https://pdf-redaction.com/apikeys/usage/)
#
# Put API Key to the env variable `PDF_REDACTION_API_KEY` or to `.env` file.
#
# ## Limitations for free version
# * 1 page per request
# * 50 Free requests per month
# * 5 requests per minute

# %% [markdown]
# ## Installing dependencies for displaying PDF files

# %%
# %%bash
# if [[ "$OSTYPE" == "linux-gnu"* ]]; then
#     echo "Detected Linux. Installing poppler-utils..."
#     apt-get install -y poppler-utils wget
# elif [[ "$OSTYPE" == "darwin"* ]]; then
#     echo "Detected macOS. Installing poppler..."
#     brew install poppler wget
# else
#     echo "Unsupported OS: $OSTYPE"
# fi

# %%
# %pip install requests pdf2image pillow python-dotenv

# %% [markdown]
# ## Downloading example PDF files

# %%
# !wget https://raw.githubusercontent.com/StabRise/pdf-redaction-api/refs/heads/main/examples/pdfs/SampleWithSignatures.pdf
# Out:
# --2026-03-22 16:49:09--  https://raw.githubusercontent.com/StabRise/pdf-redaction-api/refs/heads/main/examples/pdfs/SampleWithSignatures.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 594678 (581K) [application/octet-stream]
# Saving to: ‘SampleWithSignatures.pdf.1’
#
# SampleWithSignature 100%[===================>] 580.74K  --.-KB/s    in 0.1s
#
# 2026-03-22 16:49:09 (5.61 MB/s) - ‘SampleWithSignatures.pdf.1’ saved [594678/594678]

# %% [markdown]
# # Display original PDF

# %%
from pdf2image import convert_from_path
from IPython.display import display


# File path to your PDF (replace with your actual file path)
file_path = "./SampleWithSignatures.pdf"
# or use local file from example folder
file_path = "../examples/pdfs/SampleWithSignatures.pdf"

def display_pdf(pdf_path):
    """Display first page of the pdf file"""
    # Convert first page of PDF to image
    pages = convert_from_path(pdf_path, first_page=1, last_page=1)  # returns a list of PIL Images

    # Display first page
    display(pages[0])

display_pdf(file_path)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200>

# %% [markdown]
# # Redact PDF using API

# %%
import requests
from pathlib import Path
import base64
import json
import os
from dotenv import load_dotenv

load_dotenv()

pdf_redaction_api_base_url = os.environ.get(
    "PDF_REDACTION_API_BASE_URL",
    "https://api.pdf-redaction.com/api")

pdf_redaction_api_key = os.environ.get("PDF_REDACTION_API_KEY")

# Assemble full URL
pdf_redaction_api_url = f"{pdf_redaction_api_base_url}/anonymize/pdf"

# Define the tags to redact, if not specified all tags will be redacted
tags = [
    "DATE",
    "PERSON_NAME",
    "ORGANIZATION",
    "LOCATION",
    "EMAIL",
    "PHONE",
    "ID",
    "ACCOUNT",
    "ZIP_CODE",
    "ADDRESS",
    "IP",
    "URL",
    "SSN",
    "DRIVER_LICENSE",
    "PASSPORT",
    "AGE",
    "CREDIT_CARD",
    "SIGNATURE"
]

# Create output directory path
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)  # Create output directory if it doesn't exist

# Compute output file name based on input file name
input_file = Path(file_path)
output_file_path = output_dir / f"redacted_{input_file.name}"

headers = {
    "accept": "application/pdf",
    "X-API-Key": pdf_redaction_api_key,
}

# Read the PDF file and send it to the API
with open(file_path, "rb") as f:
    pdf_decoded = base64.b64encode(f.read()).decode("utf-8")
    response = requests.post(pdf_redaction_api_url,
                             headers=headers,
                             json={
                                 "pdf": pdf_decoded,
                                 "tags": tags,
                                 "rotated_text": False,
                                 "force_ocr": False,
                             })

print("Status code:", response.status_code)

# Save the redacted PDF to a file
if response.status_code == 200:
    print(response)
    result = response.json()

    pdf_data = result["pdf"].encode()
    content = base64.b64decode(pdf_data)

    with open(output_file_path, "wb") as out:
        out.write(content)
    print(f"Redacted PDF saved as '{output_file_path}'.")
else:
    print("Error:", response.json())
# Out:
# Status code: 200
# <Response [200]>
# Redacted PDF saved as 'output/redacted_SampleWithSignatures.pdf'.

# %% [markdown]
# ## Display processing time

# %%
print(json.dumps(result['processing_time'], indent=4))
# Out:
# {
#     "total": 1.9543,
#     "stages": {
#         "PdfDataToSingleImage": 0.3854,
#         "PdfDataToDocument": 0.0092,
#         "Ocr": 0.0014,
#         "SignatureDetector": 0.796,
#         "Ner": 0.3719,
#         "ImageDrawBoxes": 0.3064,
#         "SingleImageToPdf": 0.0838
#     }
# }

# %% [markdown]
# ## Display detected PII

# %%
print(json.dumps(result['detected_pii'], indent=4))
# Out:
# {
#     "path": "memory",
#     "entities": [
#         {
#             "entity_group": "URL",
#             "score": 0.0,
#             "word": "https://stabrise.com/scaledp/ info@stabrise.com",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "https://stabrise.com/scaledp/",
#                     "score": 1.0,
#                     "x": 994,
#                     "y": 650,
#                     "width": 580,
#                     "height": 51,
#                     "angle": 0.0
#                 },
#                 {
#                     "text": "info@stabrise.com",
#                     "score": 1.0,
#                     "x": 1094,
#                     "y": 771,
#                     "width": 379,
#                     "height": 51,
#                     "angle": 0.0
#                 }
#             ]
#         },
#         {
#             "entity_group": "URL",
#             "score": 0.0,
#             "word": "https://pdf-redaction.com https://pdf-redaction.com",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "https://pdf-redaction.com",
#                     "score": 1.0,
#                     "x": 1032,
#                     "y": 1014,
#                     "width": 504,
#                     "height": 51,
#                     "angle": 0.0
#                 },
#                 {
#                     "text": "https://pdf-redaction.com",
#                     "score": 1.0,
#                     "x": 1791,
#                     "y": 3039,
#                     "width": 458,
#                     "height": 46,
#                     "angle": 0.0
#                 }
#             ]
#         },
#         {
#             "entity_group": "PHONE",
#             "score": 0.0,
#             "word": "+48790844156",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "+48790844156",
#                     "score": 1.0,
#                     "x": 1429,
#                     "y": 3096,
#                     "width": 279,
#                     "height": 46,
#                     "angle": 0.0
#                 }
#             ]
#         },
#         {
#             "entity_group": "EMAIL",
#             "score": 0.0,
#             "word": "info@pdf-redaction.com",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "info@pdf-redaction.com",
#                     "score": 1.0,
#                     "x": 1807,
#                     "y": 3096,
#                     "width": 442,
#                     "height": 46,
#                     "angle": 0.0
#                 }
#             ]
#         },
#         {
#             "entity_group": "ZIP_CODE",
#             "score": 0.0,
#             "word": "05-270",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "05-270",
#                     "score": 1.0,
#                     "x": 1201,
#                     "y": 3096,
#                     "width": 129,
#                     "height": 46,
#                     "angle": 0.0
#                 }
#             ]
#         },
#         {
#             "entity_group": "LOCATION",
#             "score": 0.0,
#             "word": "Poland, Marki, Wilcza 19i/2,",
#             "start": 0,
#             "end": 0,
#             "boxes": [
#                 {
#                     "text": "Poland,",
#                     "score": 1.0,
#                     "x": 676,
#                     "y": 3096,
#                     "width": 141,
#                     "height": 46,
#                     "angle": 0.0
#                 },
#                 {
#                     "text": "Marki,",
#                     "score": 1.0,
#                     "x": 829,
#                     "y": 3096,
#                     "width": 113,
#                     "height": 46,
#                     "angle": 0.0
#                 },
#                 {
#                     "text": "Wilcza",
#                     "score": 1.0,
#                     "x": 954,
#                     "y": 3096,
#                     "width": 122,
#                     "height": 46,
#                     "angle": 0.0
#                 },
#                 {
#                     "text": "19i/2,",
#                     "score": 1.0,
#                     "x": 1088,
#                     "y": 3096,
#                     "width": 101,
#                     "height": 46,
#                     "angle": 0.0
#                 }
#             ]
#         }
#     ],
#     "exception": "",
#     "json": ""
# }

# %% [markdown]
# ## Display redacted PDF

# %%
display_pdf(output_file_path)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1654x2339>
